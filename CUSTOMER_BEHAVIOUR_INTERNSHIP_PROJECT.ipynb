# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramya-1026/Customer_Behavior_Analysis/blob/main/CUSTOMER_BEHAVIOUR_INTERNSHIP_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CUSTOMER_SHOPPING_BEHAVIOUR

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/amlanmohanty1/customer-trends-data-analysis-SQL-Python-PowerBI/main/customer_shopping_behavior.csv"

df = pd.read_csv(url)
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.head() #top 5 rows and we can already get the sense of data how our data looks
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()#but looking at data alone is not enough right we also want to know overall structute how many rows,columns and datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
# Numerical summary
df.describe()

# Categorical summary
df.describe(include='object')#to check summary statistics of columns as u can see i get the summary statistics of numerical columns by default but if u need for categorial columns also u can write include ='all'
# Out:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# count                 3900           3900             3900            3900
# unique                   2              6                2               2
# top                     No  Free Shipping               No              No
# freq                  2847            675             2223            2223
#
#        Payment Method Frequency of Purchases
# count            3900                   3900
# unique              6                      7
# top            PayPal         Every 3 Months
# freq              677                    584

# %%
df.isnull().sum()#check missing value
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %% [markdown]
# Look at column name uppercase lowercase mixed and spaces
#
# A good practice to put column names in snake casing with all lowercase and underscore

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})#im replacing purchase_amount_(usd) to purchase_amount

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
#create a column for age_group
labels=['Young Adult','Adult','Middle-Aged','Senior']
df['age_group']=pd.qcut(df['age'],q=4,labels=labels)#Q card it splits the age into four equal sizes groups based on the data distribution and assign labels be defined.

# %%
df[['age','age_group']].head(10)#Original ages alongside the new age group column, now it is easier to analyze pattern across different age category which can be really useful for marketing, understanding the customer behavior.
# Out:
#    age    age_group
# 0   55  Middle-Aged
# 1   19  Young Adult
# 2   50  Middle-Aged
# 3   21  Young Adult
# 4   45  Middle-Aged
# 5   46  Middle-Aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middle-Aged

# %% [markdown]
# So right now, the dataset has a column called frequency of purchases, which tells us how often a customer shops, but it's in text form, like weekly, monthly, or quarterly. And you know that working with text makes analysis harder, especially if you want to calculate metrics or compare customers. So what we'll do is we'll convert these textual frequencies into numbers, basically the number of days between purchases. And this will help us make our analysis much easier.

# %%
#create column purchase_frequency_days
frequency_mapping={
    'Fortnightly':14,
    'Weekly':7,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Annually':365,
    'Every 3 Months':90
}
df['purchase_frequency_days']=df['frequency_of_purchases'].map(frequency_mapping)

# %% [markdown]
# Alongside the new numeric column, now instead of just seeing weekly or monthly, you can see the exact number of days between purchases for each customer. And believe me, this is super useful for analysis.

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                     14.0            Fortnightly
# 1                     14.0            Fortnightly
# 2                      7.0                 Weekly
# 3                      7.0                 Weekly
# 4                    365.0               Annually
# 5                      7.0                 Weekly
# 6                     90.0              Quarterly
# 7                      7.0                 Weekly
# 8                    365.0               Annually
# 9                     90.0              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
# (df['discount_applied'] == df['promo_code_used']).all() # This line caused an error because 'promo_code_used' column was already dropped.

# %% [markdown]
# both discount applied and promo_code_used are same data so we are dropping promo_code_ used

# %%
# df = df.drop('promo_code_used',axis=1) # This line caused an error because 'promo_code_used' column was already dropped.

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group',
#        'purchase_frequency_days'],
#       dtype='object')

# %% [markdown]
# now see above pormo_code_used column is dropped

# %% [markdown]
# All right, now that we've done some data exploration and initial data analysis with our dataset, let's take the next step and move this dataset into PostgreSQL so that we can run SQL queries to do some deeper data analysis and answer some business questions. First things first, we need a database to store our data. So open up pgAdmin and create a new database. Right-click on databases, select...

# %%
# !pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 53.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# I used Neon (a cloud-hosted PostgreSQL database) because Google Colab runs on the internet and cannot access my local pgAdmin database (localhost). Neon allows me to connect my Colab environment to a remote database and store data easily.

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://neondb_owner:npg_dWgcuk4RjDi3@ep-dawn-surf-a1r9v3b0-pooler.ap-southeast-1.aws.neon.tech/neondb",
    connect_args={"sslmode": "require"}
)

df.to_sql("customer", engine, if_exists="replace", index=False)

print("✅ Data uploaded successfully!")
# Out:
# ✅ Data uploaded successfully!

# %% [markdown]
# 1. Age Distribution

# %%
import matplotlib.pyplot as plt

plt.hist(df['age'], bins=10)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 2. Category Analysis

# %%
df['category'].value_counts().plot(kind='bar')
plt.title("Product Category Analysis")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 3. Gender Distribution

# %%
df['gender'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 4. Purchase Amount Distribution

# %%
plt.hist(df['purchase_amount'], bins=10)
plt.title("Purchase Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 5. Correlation Heatmap

# %%
import seaborn as sns

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()
